# %% [markdown]
# > . - любой символ
# >\\. - точка

# %% [markdown]
# [нл] — только «н» и «л»
#
# [а-я] — все русские буквы в нижнем регистре от «а» до «я» (кроме «ё»)
#
# [А-Я]    — все заглавные русские буквы
#
# [А-Яа-яЁё]  — все русские буквы
#
# [a-z]  — латиница мелким шрифтом
#
# [a-zA-Z]  — все английские буквы
#
# [0-9]  — любая цифра
#
# [В-Ю]   — буквы от «В» до «Ю» (да, диапазон — это не только от А до Я)
#
# [А-ГО-Р]   — буквы от «А» до «Г» и от «О» до «Р»

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import re

finding = re.compile(r'[]+(\w+)[]+group[1]')

text = 'Поздравляем! Что что что вы вы прошли вы на на новый уровень уровень.'

finding.findall(text)
# Out:
# []

# %% [markdown]
# ![image.png](attachment:image.png)
